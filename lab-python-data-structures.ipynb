# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
#
# 2. Create an empty dictionary called `inventory`.
#
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.
#
# 4. Create an empty set called `customer_orders`.
#
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.
#
# 6. Print the products in the `customer_orders` set.
#
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.
# inventory = {
#     "apple": 10,
#     "banana": 20,
#     "orange": 15
#
#
#
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.
#
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.
#
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.

# %%
Excercise #1

# %%
products = ['t-shirt','mug', 'hat','book','keychain']

# %%
Exercise #2

# %%
inventory = { }

# %%
inventory = { }
Key1 = [input('enter a product')]
inventory['t-shirt'] =int(input("enter a value"))
Key2 = [input('enter a product')]
inventory['mug'] =int(input("enter a value")) 
Key3 = [input('enter a product')]
inventory['hat'] =int(input("enter a value"))
Key4 = [input('enter a product')]
inventory['book'] =int(input("enter a value"))
Key5 = [input('enter a product')]
inventory['keychain'] =int(input("enter a value"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 3
#       1 inventory = { }
#       2 Key1 = [input('enter a product')]
# ----> 3 inventory['t-shirt'] =int(input("enter a value"))
#       4 Key2 = [input('enter a product')]
#       5 inventory['mug'] =int(input("enter a value"))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
type(inventory)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(inventory)
#
# NameError: name 'inventory' is not defined

# %%
Exercise #3

# %%
inventory["mug"] =int(input("Enter the available quantity for mug: "))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 inventory["mug"] =int(input("Enter the available quantity for mug: "))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
mug = 10
tshirt = 25
hat =15
book = 8
keychain = 50
inventory.append(mug)
inventory.append(shirt)
inventory.append(hat)
inventory.append(book)
inventory.append(keychain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       4 book = 8
#       5 keychain = 50
# ----> 6 inventory.append(mug)
#       7 inventory.append(shirt)
#       8 inventory.append(hat)
#
# NameError: name 'inventory' is not defined

# %%
inventory[mug]=10
inventory[tshirt]=25
inventory[hat]=15
inventory[book]=8
inventory[keychain]=50

# %%
Excercise #4

# %%
customer_order = []

# %%
Excercise #5

# %%
product = input("name three products the customer wants to order from the inventory separated by commas:") ")
# Out:
#   Cell In[3], line 1
#     product = input("name three products the customer wants to order from the inventory separated by commas:") ")
#                                                                                                                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
Excercise #6

# %%
print(product)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(product)
#
# NameError: name 'product' is not defined

# %%
Excercise #7

# %%
inventory = {
    "apple": 10,
    "banana": 20,
    "orange": 15
}

customer_orders = {"apple", "banana", "apple"}

total_products_ordered = len(customer_orders)

available_products = sum(inventory.values())

percentage_ordered = (total_products_ordered / available_products) * 100

order_status = (total_products_ordered, percentage_ordered)
print("Order status:", order_status)
# Out:
# Order status: (2, 4.444444444444445)

# %%
Excercise #8

# %%
inventory = {
    "apple": 10,
    "banana": 20,
    "orange": 15
}

customer_orders = {"apple", "banana", "apple"}

total_products_ordered = len(customer_orders)

available_products = sum(inventory.values())

percentage_ordered = (total_products_ordered / available_products) * 100

order_status = (total_products_ordered, percentage_ordered)

print("Order Statistics:")
print(f"Total Products Ordered: {total_products_ordered}")
print(f"Percentage of Products Ordered: {percentage_ordered:.2f}%")
# Out:
# Order Statistics:
# Total Products Ordered: 2
# Percentage of Products Ordered: 4.44%

# %%
Excercise #9

# %%
inventory = {
    "apple": 10,
    "banana": 20,
    "orange": 15
}

# Subtract 1 from the quantity of each product
for product in inventory:
    inventory[product] -= 1

print("Updated inventory:", inventory)
# Out:
# Updated inventory: {'apple': 9, 'banana': 19, 'orange': 14}

# %%
Excercise #10
